# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_json('./scoreboard.json')

# %%
df.head()
# Out:
#                                  teamName  ...  country
# 0                                   ✷code  ...    Japan
# 1                              Past Glory  ...  Ukraine
# 2  WADA won't ban us for Guinness, right?  ...  Germany
# 3                                AtCoDeer  ...    Japan
# 4                                 Errecto  ...   Poland
#
# [5 rows x 6 columns]

# %%
scores = df.score
deltas = [ scores[n-1] - scores[n] for n in range(1,len(scores))][::-1]

# %%
plt.figure(figsize=(20, 20))
plt.plot(deltas)
